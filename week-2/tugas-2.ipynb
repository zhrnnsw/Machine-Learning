# %% [markdown]
# <a href="https://colab.research.google.com/github/zhrnnsw/Machine-Learning/blob/main/week-2/tugas-2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Laporan Praktikum Pertemuan 2**
#
# # **Tugas Praktikum**
#
# Mendiagnonis jenis kanker Malignant (M) dan Benign (B) menggunakan data "Wisconsin Breast Cancer".
#
# 1. Pisahkan antara variabel yang dapat digunakan dan variabel yang tidak dapat digunakan.

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler
dpath = 'data/wbc.csv'
df = pd.read_csv(dpath)
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %%
df = df.drop(['id','Unnamed: 32'],axis=1)

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   diagnosis                569 non-null    object
#  1   radius_mean              569 non-null    float64
#  2   texture_mean             569 non-null    float64
#  3   perimeter_mean           569 non-null    float64
#  4   area_mean                569 non-null    float64
#  5   smoothness_mean          569 non-null    float64
#  6   compactness_mean         569 non-null    float64
#  7   concavity_mean           569 non-null    float64
#  8   concave points_mean      569 non-null    float64
#  9   symmetry_mean            569 non-null    float64
#  10  fractal_dimension_mean   569 non-null    float64
#  11  radius_se                569 non-null    float64
#  12  texture_se               569 non-null    float64
# ...

# %% [markdown]
# ---
#
#
# 2.  Lakukan proses encoding pada kolom "diagnosis".

# %%
le = LabelEncoder() # membuat objek dari LabelEncoder
df['diagnosis'] = le.fit_transform(df['diagnosis']) # proses encoding

# %%
df.head(20)
# Out:
#     diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0           1        17.99         10.38          122.80     1001.0
# 1           1        20.57         17.77          132.90     1326.0
# 2           1        19.69         21.25          130.00     1203.0
# 3           1        11.42         20.38           77.58      386.1
# 4           1        20.29         14.34          135.10     1297.0
# 5           1        12.45         15.70           82.57      477.1
# 6           1        18.25         19.98          119.60     1040.0
# 7           1        13.71         20.83           90.20      577.9
# 8           1        13.00         21.82           87.50      519.8
# 9           1        12.46         24.04           83.97      475.9
# 10          1        16.02         23.24          102.70      797.8
# 11          1        15.78         17.89          103.60      781.0
# 12          1        19.17         24.80          132.40     1123.0
# ...

# %%
df.to_csv('wbc.csv') # untuk mengimpan file

# %% [markdown]
# ---
#
#
# 3. Lakukan proses standarisasi pada semua kolom yang memiliki nilai numerik.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

def standardize_numeric_columns(dpath):
    # Read the CSV file
    df = pd.read_csv(dpath)

    # Select columns with numeric data types
    numeric = df.select_dtypes(include=['int64', 'float64']).columns

# %%
df = df[df.columns.difference(['diagnosis'])] # untuk memanggil semua kolom kecuali kolom diagnosis

# %%
df.head()
# Out:
#    area_mean  area_se  area_worst  compactness_mean  compactness_se  \
# 0     1001.0   153.40      2019.0           0.27760         0.04904
# 1     1326.0    74.08      1956.0           0.07864         0.01308
# 2     1203.0    94.03      1709.0           0.15990         0.04006
# 3      386.1    27.23       567.7           0.28390         0.07458
# 4     1297.0    94.44      1575.0           0.13280         0.02461
#
#    compactness_worst  concave points_mean  concave points_se  \
# 0             0.6656              0.14710            0.01587
# 1             0.1866              0.07017            0.01340
# 2             0.4245              0.12790            0.02058
# 3             0.8663              0.10520            0.01867
# 4             0.2050              0.10430            0.01885
#
#    concave points_worst  concavity_mean  ...  radius_worst  smoothness_mean  \
# 0                0.2654          0.3001  ...         25.38          0.11840
# ...

# %% [markdown]
# ---
#
# 4. Lakukan proses stratified split data untuk membuat data latih dan data uji dengan rasio 80:20.

# %%
import pandas as pd

df = pd.read_csv('data/wbc.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Split data
from sklearn.model_selection import train_test_split
dpath = 'data/wbc.csv'
df = pd.read_csv(dpath)
df.head()

# Split data training dan dan lainnya
# data lainnya, akan kita split lagi menjadi validasi dan testing.
# Rasio yang akan kita gunakan adalah 80:20
df_train, df_test = train_test_split(df, test_size=0.2, stratify=df['diagnosis'])

# Cek masing-masing ukuran data

print(f'Jumlah label data asli:\n{df.diagnosis.value_counts()}')
print(f'Jumlah label data train:\n{df_train.diagnosis.value_counts()}')
print(f'Jumlah label data test:\n{df_test.diagnosis.value_counts()}')
# Out:
# Jumlah label data asli:
# B    357
# M    212
# Name: diagnosis, dtype: int64
# Jumlah label data train:
# B    285
# M    170
# Name: diagnosis, dtype: int64
# Jumlah label data test:
# B    72
# M    42
# Name: diagnosis, dtype: int64
